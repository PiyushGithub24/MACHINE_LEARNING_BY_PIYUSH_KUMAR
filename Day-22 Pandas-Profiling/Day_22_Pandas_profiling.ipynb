# %% [markdown]
# <a href="https://colab.research.google.com/github/PiyushGithub24/MACHINE_LEARNING_BY_PIYUSH_KUMAR/blob/main/Day_22_Pandas_profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas-profiling :--

# %%
import pandas as pd
import seaborn as sns

# %%
titanic=sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic_sample = titanic.sample(frac=0.6, random_state=1)  # Use 10% of the data

# %%
titanic_sample.shape
# Out:
# (535, 15)

# %%
#pip install pandas-profiling

# %%
# # Uninstall conflicting versions
# !pip uninstall -y pandas-profiling pydantic

# # Install compatible versions
# !pip install pandas-profiling==3.6.3 pydantic==1.10.7

# # Restart the runtime manually in the Colab interface

# %%
import pandas_profiling
from pandas_profiling import ProfileReport

# Assuming you have a DataFrame named 'titanic'
prof = ProfileReport(titanic_sample)
prof.to_file(output_file="output.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
